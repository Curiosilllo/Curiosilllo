# %% [markdown]
# # Temario Tentativo (todo lo que sale aquí está sin hacer)
#
# ## Programación y Python
# ### Introducción
# ### Historia Python
# ### Instalación entorno trabajo (Anaconda + Jupyter-notebook?)
#
# ## Python básico
# ### Ejemplos básicos "Hola Mundo"
# ### Manejo de archivos: leer / escribir TXT, CSV, JSON
# ### Procesamiento de archivos por lotes: renombrar, mover, copiar
#
# ## Introducción a la astronomía
# ### Objetos celestes
# ### Sistemas de coordenadas astronómicos y terrestres
# ### Instrumental astronómico
#
#
# ## Imágenes digitales
# ### Vectorial VS. bitmap
# ### Compresión de imágenes
# ### JPEG + PNG + TIFF.... Conversión entre formatos.
# ### FITS. FITS multidimensionales.
# ### Lectura, manipulación, visualización y conversión de ficheros FITS. (incluyendo paquete visualization)
# ### Vídeo: Vídeo a fotogramas, fotogramas a vídeo
#
# ## Procesamiento de imágenes
# ### Conversión entre espacios de color
# ### Recortes
# ### Escalados
# ### Rotaciones
# ### Alineación de fotogramas
# ### Rutinas útiles para astronomía: sigma_clipping, cálculo del FWHM, modelado de datos, medias, medianas, etc.
# ### Convoluciones
#
# ## Astrofotografía
# ### Lucky imaging y técnicas de apilado de fotogramas
# ### Obtener imágenes a color a partir de imágenes monobanda
# ### Funciones de mejora del aspecto de las imágenes (convoluciones, eliminación de ruido, HDR)
#
# ## Obtención de información
# ### Determinando la posición de los objetos celestes en el cielo (y graficarla). Paquete Astroplan
# ### Búsqueda en formularios online y bases de datos astronómicas (paquete Astroquery)
# ### Web scraping básico
#
#
# ## Astrometría y Fotometría
# ### Resolución de placas astronómicas con Astrometry.net
# ### Fotometría: Detectando fuentes en imágenes astronómicas y sus parámetros morfológicos
# ### Registro y alineado de series de imágenes
# ### Ejemplos prácticos: ocultaciones astronómicas y detección de exoplanetas
#
#
#
# ## Manejo de instrumental astronómico
# ### Instrument-Neutral-Distributed-Interface: Protocolo INDI para el control de dispositivos
# ### Disparando fotografías con una cámara de fotos estándar. Aplicación para la creación de time-lapses
# ### Apuntando el telescopio y tomando imágenes desde Python
# ### Ejemplo práctico de control
# ### Creación de instrumental astronómico con microcontroladores basados en Python y componentes eléctricos y electrónicos estándar
#
#
# ## BIBLIOGRAFÍA / WEBGRAFÍA
#
# + Astropython: Tutorials, API, Reference... http://www.astropython.org/
# + INDI Lib: http://indilib.org/
# + Statistics, Data Mining, and Machine Learning in Astronomy: A Practical Python Guide for the Analysis of Survey Data (Princeton Series in Modern Observational Astronomy),  Željko Ivezić and Andrew J. Connolly
# + Numerical Python in Astronomy and Astrophysics: A Practical Guide to Astrophysical Problem Solving (Undergraduate Lecture Notes in Physics)  Wolfram Schmidt (Autor), Marcel Völschow (Autor) Springer
# + Python Programs for Astronomical Solutions: Planetary Positions, Lunar and Solar Eclipses, Pictures, Videos and Maps,  Manohar Narayan Purohit (Autor) Notion Press
